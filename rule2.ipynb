# %%
import os; import sys; import re

# common spark import
from pyspark import SparkFiles
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql.window import Window
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType

# connect to spark if we haven't already
if not 'spark' in locals():
  spark = SparkSession.builder \
      .master("local[*]") \
      .appName('development') \
      .config("spark.sql.debug.maxToStringFields", str(1024 * 1024)) \
      .getOrCreate()
  sc = spark.sparkContext

print("Connected to Spark!")
# Out:
# Connected to Spark!

# %% [markdown]
# # Test Data

# %%
data = [("Main St","","","99"),
        ("75 Joseph Ave","Apt 205","","75"),
        ("Algonquin Way","","","99"),
        ("2 Muirfield Run","","","02"),
        ("1950 N Point Blvd","","","50"),
        ("N8603 Carper Rd","","","03"),
        ("1234A MAIN ST","","","34"),
        ("HC 1 Box 1264","","","64"),
        ("525 Circle Dr","","","25"),
        ("RR Box AA","","","99"),
        ("A Main St","Apt 12","","99")]

columns = ["address_line_1","address_line_2","dpc","expected_dpc"]
df_test = spark.createDataFrame(data = data, schema = columns)

# %%
df_test.show()
# Out:
# +-----------------+--------------+---+------------+
# |   address_line_1|address_line_2|dpc|expected_dpc|
# +-----------------+--------------+---+------------+
# |          Main St|              |   |          99|
# |    75 Joseph Ave|       Apt 205|   |          75|
# |    Algonquin Way|              |   |          99|
# |  2 Muirfield Run|              |   |          02|
# |1950 N Point Blvd|              |   |          50|
# |             RR 1|              |   |          99|
# |  N8603 Carper Rd|              |   |          03|
# |    1234A MAIN ST|              |   |          34|
# |    HC 1 Box 1264|              |   |          64|
# |    525 Circle Dr|              |   |          25|
# |        RR Box AA|              |   |          99|
# |        A Main St|        Apt 12|   |          99|
# +-----------------+--------------+---+------------+

# %%
df_test = df_test.withColumn('housenumber', 
                             (f.regexp_extract(f.col('address_line_1'),'(^[0-9]([0-9A-Z.*-]+)?)', 1)))
df_test.show()
# Out:
# +-----------------+--------------+---+------------+-----------+
# |   address_line_1|address_line_2|dpc|expected_dpc|housenumber|
# +-----------------+--------------+---+------------+-----------+
# |          Main St|              |   |          99|           |
# |    75 Joseph Ave|       Apt 205|   |          75|         75|
# |    Algonquin Way|              |   |          99|           |
# |  2 Muirfield Run|              |   |          02|          2|
# |1950 N Point Blvd|              |   |          50|       1950|
# |             RR 1|              |   |          99|           |
# |  N8603 Carper Rd|              |   |          03|           |
# |    1234A MAIN ST|              |   |          34|      1234A|
# |    HC 1 Box 1264|              |   |          64|           |
# |    525 Circle Dr|              |   |          25|        525|
# |        RR Box AA|              |   |          99|           |
# |        A Main St|        Apt 12|   |          99|           |
# +-----------------+--------------+---+------------+-----------+

# %%
# rule 1
#df_test = df_test.withColumn('dpc', (f.regexp_extract(f.col('address_line_1'),'(^[0-9]([0-9A-Z.*-]+)?)', 1)))
df_test = df_test.withColumn('dpc', f.when((f.col('address_line_2') == "") &
(f.col('housenumber')).isNotNull() & f.col('housenumber').rlike('^[0-9]*$'),
(f.regexp_extract(f.col('housenumber'),'(\d+)',1)).substr(-2,2)
).otherwise(f.col('dpc')))
df_test.show()
# Out:
# +-----------------+--------------+---+------------+-----------+
# |   address_line_1|address_line_2|dpc|expected_dpc|housenumber|
# +-----------------+--------------+---+------------+-----------+
# |          Main St|              |   |          99|           |
# |    75 Joseph Ave|       Apt 205|   |          75|         75|
# |    Algonquin Way|              |   |          99|           |
# |  2 Muirfield Run|              |  2|          02|          2|
# |1950 N Point Blvd|              | 50|          50|       1950|
# |             RR 1|              |   |          99|           |
# |  N8603 Carper Rd|              |   |          03|           |
# |    1234A MAIN ST|              |   |          34|      1234A|
# |    HC 1 Box 1264|              |   |          64|           |
# |    525 Circle Dr|              | 25|          25|        525|
# |        RR Box AA|              |   |          99|           |
# |        A Main St|        Apt 12|   |          99|           |
# +-----------------+--------------+---+------------+-----------+

# %%
# rule 2
df_test = df_test.withColumn('dpc', 
                   f.when((f.col('dpc') == "") & (f.col('housenumber') == ""), 
                          f.lit('99'))
                   .otherwise(f.col('dpc'))
                  )
df_test.show()
# Out:
# +-----------------+--------------+---+------------+-----------+
# |   address_line_1|address_line_2|dpc|expected_dpc|housenumber|
# +-----------------+--------------+---+------------+-----------+
# |          Main St|              | 99|          99|           |
# |    75 Joseph Ave|       Apt 205|   |          75|         75|
# |    Algonquin Way|              | 99|          99|           |
# |  2 Muirfield Run|              |  2|          02|          2|
# |1950 N Point Blvd|              | 50|          50|       1950|
# |             RR 1|              | 99|          99|           |
# |  N8603 Carper Rd|              | 99|          03|           |
# |    1234A MAIN ST|              |   |          34|      1234A|
# |    HC 1 Box 1264|              | 99|          64|           |
# |    525 Circle Dr|              | 25|          25|        525|
# |        RR Box AA|              | 99|          99|           |
# |        A Main St|        Apt 12| 99|          99|           |
# +-----------------+--------------+---+------------+-----------+

# %%
#if address line 1 does not start with a number, use 99
#from pyspark.sql.functions import col, when

#df2 = df_test.withColumn('dpc', f.when(f.col('address_line_1') == 'Main St', f.lit('99'))
                    #.otherwise(f.col('dpc')))

#df2.show()

# %%
#pattern = '^[a-z,A-Z]{2,}\s[a-z,A-Z]+'

#df3 = df_test.withColumn('dpc', 
                    f.when(f.col('address_line_1').rlike(pattern), f.lit('99'))
                    .otherwise(f.col('dpc')))

# %% [markdown]
# # Dataframe

# %%
df = spark.read.option("header", "true").csv("address-linkage-key/address_link/data/test/*medium*.gz")
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit
# 0        525 Circle Dr           None           25                    0
# 1    2312 Primrose Ave           None           12                    2
# 2  849 Gardenstone Cir           None           49                    8
# 3    7511 Briarwood Dr           None           11                    0
# 4       1071 S 15th St           None           71                    4
# 5         206 Front St         Apt 4B           42                    1
# 6     1295 Millpond Rd           None           95                    1
# 7      479 Glenwood Ln           None           79                    8
# 8       2150 NW 9th St        Apt 105           30                    9
# 9       460 10th St NE           None           60                    0

# %%
df = df.withColumn('dpc', f.lit(None))

# %%
df = df.withColumn('housenumber', (f.regexp_extract(f.col('address_line_1'),'(^[0-9]([0-9A-Z.*-]+)?)', 1)))

# %%
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit   dpc  \
# 0        525 Circle Dr           None           25                    0  None
# 1    2312 Primrose Ave           None           12                    2  None
# 2  849 Gardenstone Cir           None           49                    8  None
# 3    7511 Briarwood Dr           None           11                    0  None
# 4       1071 S 15th St           None           71                    4  None
# 5         206 Front St         Apt 4B           42                    1  None
# 6     1295 Millpond Rd           None           95                    1  None
# 7      479 Glenwood Ln           None           79                    8  None
# 8       2150 NW 9th St        Apt 105           30                    9  None
# 9       460 10th St NE           None           60                    0  None
#
#   housenumber
# 0         525
# 1        2312
# 2         849
# 3        7511
# 4        1071
# 5         206
# 6        1295
# 7         479
# 8        2150
# 9         460

# %%
#rule1
df = df.withColumn('dpc', f.when((f.col('address_line_2').isNull()) &
(f.col('housenumber')).isNotNull() & f.col('housenumber').rlike('^[0-9]*$'),
(f.regexp_extract(f.col('housenumber'),'(\d+)',1)).substr(-2,2)
).otherwise(f.col('dpc')))
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit   dpc  \
# 0        525 Circle Dr           None           25                    0    25
# 1    2312 Primrose Ave           None           12                    2    12
# 2  849 Gardenstone Cir           None           49                    8    49
# 3    7511 Briarwood Dr           None           11                    0    11
# 4       1071 S 15th St           None           71                    4    71
# 5         206 Front St         Apt 4B           42                    1  None
# 6     1295 Millpond Rd           None           95                    1    95
# 7      479 Glenwood Ln           None           79                    8    79
# 8       2150 NW 9th St        Apt 105           30                    9  None
# 9       460 10th St NE           None           60                    0    60
#
#   housenumber
# 0         525
# 1        2312
# 2         849
# 3        7511
# 4        1071
# 5         206
# 6        1295
# 7         479
# 8        2150
# 9         460

# %%
# rule 2
df = df.withColumn('dpc', 
                   f.when((f.col('dpc').isNull()) & (f.col('housenumber').isNull()), 
                          f.lit('99'))
                   .otherwise(f.col('dpc'))
                  )

# %%
df.limit(50).toPandas()
# Out:
#    predirection      streetname streetsuffix postdirection unitdesignator  \
# 0                        Circle         Dr
# 1                      Primrose         Ave
# 2                   Gardenstone         Cir
# 3                     Briarwood         Dr
# 4            S             15th         St
# 5                         Front         St                         Apt
# 6                      Millpond         Rd
# 7                      Glenwood         Ln
# 8            NW             9th         St                         Apt
# 9                          10th         St              NE
# 10                      Hil Mar         Dr                         Apt
# 11                       PO Box
# 12                          Ash         St
# 13           N             11th         St
# 14                          Ely         St
# 15                      Stroika         Ct
# 16               Music Mountain         Rd                         Lot
# 17           N              300                         E
# 18           NW            30th         Ct                         Apt
# 19                       PO Box
# 20                   Cedar Hill         Rd
# 21                        249th         Ave
# 22                 Castle Tower         Rd
# 23                    Faircrest         St              SW
# 24                       Jasper         Dr
# 25                      Watkins         Ct
# 26                   Goldenwood         Dr
# 27                         Maes         Rd
# 28           W           Old 67
# 29                        Scale         Rd
# 30                         West         St
# 31                       Kinard         Rd
# 32           N             46th         Ave
# 33                         Pine         St
# 34                 Holly Spring         Dr
# 35                 Mystic Bluff         Ln
# 36                       Orense         Dr
# 37                  Long Hollow         Rd
# 38                  Stony Ridge         Way
# 39                      Melrose         Blvd
# 40           S       Sturbridge         Rd
# 41           E           Fowler         Ave
# 42           W      Evans Creek         Rd
# 43                     Cal Bost         Rd
# 44                    Riceville         Rd
# 45                 Scott Wright         Rd
# 46                     Okaloosa         Ave
# 47                   Debbie Sue         Rd
# 48                       PO Box
# 49                      Wickham         Ave
#
#    unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                          Fort Morgan    CO  80701   3419            S
# 1                                Vista    CA  92083   8032            S
# 2                            Tallmadge    OH  44278   1085            S
# 3                            Crestwood    KY  40014   9019            S
# 4                          Saint Clair    MI  48079   5203            S
# 5              4B             Brooklyn    NY  11201   1223            M
# 6                        Elizabeth Cty    NC  27909   7551            S
# 7                          East Meadow    NY  11554   3719            S
# 8              105               Miami    FL  33125   3443            M
# 9                               Naples    FL  34120   2057            S
# 10             201        District Hts    MD  20747   4105            M
# 11                             Andover    KS  67002   0901            U
# 12                             Webster    MA  01570   3060            S
# 13                        Collinsville    OK  74021   2019            S
# 14                             Allegan    MI  49010   1419            S
# 15                             Crivitz    WI  54114   8204            S
# 16             2             Morganton    NC  28655   9917            M
# 17                          Valparaiso    IN  46383   8345            S
# 18             109       Ft Lauderdale    FL  33322   2045            M
# 19                        Olive Branch    MS  38654   2104            S
# 20                        Cuyahoga Fls    OH  44223   1239            S
# 21                               Salem    WI  53168   9518            S
# 22                       Mechanicsvlle    VA  23116   2777            S
# 23                              Canton    OH  44706   3471            S
# 24                         Stockbridge    GA  30281   4276            S
# 25                          Fort Worth    TX  76116   8545            S
# 26                          West Fargo    ND  58078   3941            S
# 27                         Murphysboro    IL  62966   4645            S
# 28                             Paragon    IN  46166   9436            S
# 29                              Benton    KY  42025   7803            S
# 30                         New Milford    CT  06776   3558            S
# 31                          Ninety Six    SC  29666   9755            S
# 32                           Hollywood    FL  33021   4115            S
# 33                            Boscobel    WI  53805   1121            S
# 34                          Germantown    TN  38138   6217            S
# 35                             Cypress    TX  77433   2261            S
# 36                           Las Vegas    NV  89138   4562            S
# 37                          Rineyville    KY  40162   9305            S
# 38                           San Diego    CA  92131   6139            S
# 39                        Pickerington    OH  43147   8437            S
# 40                            Charlton    MA  01507   1909            S
# 41                        Thonotosassa    FL  33592   2137            S
# 42                         Rogue River    OR  97537   6677            S
# 43                             Midland    NC  28107   8782            S
# 44                           Asheville    NC  28805   8708            S
# 45                           Texarkana    TX  75503   0434            S
# 46                          Valparaiso    FL  32580   1248            S
# 47                        Straw Plains    TN  37871   3703            S
# 48                            Sweetser    IN  46987   0108            U
# 49                               Bronx    NY  10469   2738            S
#
#             address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0            525 Circle Dr           None           25                    0
# 1        2312 Primrose Ave           None           12                    2
# 2      849 Gardenstone Cir           None           49                    8
# 3        7511 Briarwood Dr           None           11                    0
# 4           1071 S 15th St           None           71                    4
# 5             206 Front St         Apt 4B           42                    1
# 6         1295 Millpond Rd           None           95                    1
# 7          479 Glenwood Ln           None           79                    8
# 8           2150 NW 9th St        Apt 105           30                    9
# 9           460 10th St NE           None           60                    0
# 10         6509 Hil Mar Dr        Apt 201           51                    4
# 11              901 PO Box           None           01                    4
# 12               39 Ash St           None           39                    6
# 13           719 N 11th St           None           19                    4
# 14              404 Ely St           None           04                    7
# 15        N7255 Stroika Ct           None           55                    1
# 16  3256 Music Mountain Rd          Lot 2           02                    6
# 17             510 N 300 E           None           10                    5
# 18        10360 NW 30th Ct        Apt 109           34                    9
# 19             1992 PO Box           None           92                    6
# 20      2950 Cedar Hill Rd           None           50                    5
# 21          8116 249th Ave           None           16                    7
# 22   10184 Castle Tower Rd           None           84                    2
# 23    5713 Faircrest St SW           None           13                    0
# 24           225 Jasper Dr           None           25                    0
# 25         4209 Watkins Ct           None           09                    8
# 26      1217 Goldenwood Dr           None           17                    7
# 27              15 Maes Rd           None           15                    6
# 28           7909 W Old 67           None           09                    6
# 29           3896 Scale Rd           None           96                    4
# 30              36 West St           None           36                    4
# 31          5810 Kinard Rd           None           10                    4
# 32         1801 N 46th Ave           None           01                    9
# 33             602 Pine St           None           02                    2
# 34    2711 Holly Spring Dr           None           11                    9
# 35   17718 Mystic Bluff Ln           None           18                    6
# 36         11821 Orense Dr           None           21                    1
# 37      241 Long Hollow Rd           None           41                    5
# 38   10573 Stony Ridge Way           None           73                    5
# 39        786 Melrose Blvd           None           86                    5
# 40      17 S Sturbridge Rd           None           17                    0
# 41       9401 E Fowler Ave           None           01                    4
# 42  10565 W Evans Creek Rd           None           65                    2
# 43        2295 Cal Bost Rd           None           95                    3
# 44       2005 Riceville Rd           None           05                    9
# 45    6512 Scott Wright Rd           None           12                    6
# 46        332 Okaloosa Ave           None           32                    2
# 47       107 Debbie Sue Rd           None           07                    4
# 48              108 PO Box           None           08                    9
# 49        3418 Wickham Ave           None           18                    1
#
#      dpc housenumber
# 0     25         525
# 1     12        2312
# 2     49         849
# 3     11        7511
# 4     71        1071
# 5   None         206
# 6     95        1295
# 7     79         479
# 8   None        2150
# 9     60         460
# 10  None        6509
# 11    01         901
# 12    39          39
# 13    19         719
# 14    04         404
# 15
# 16  None        3256
# 17    10         510
# 18  None       10360
# 19    92        1992
# 20    50        2950
# 21    16        8116
# 22    84       10184
# 23    13        5713
# 24    25         225
# 25    09        4209
# 26    17        1217
# 27    15          15
# 28    09        7909
# 29    96        3896
# 30    36          36
# 31    10        5810
# 32    01        1801
# 33    02         602
# 34    11        2711
# 35    18       17718
# 36    21       11821
# 37    41         241
# 38    73       10573
# 39    86         786
# 40    17          17
# 41    01        9401
# 42    65       10565
# 43    95        2295
# 44    05        2005
# 45    12        6512
# 46    32         332
# 47    07         107
# 48    08         108
# 49    18        3418

# %%
df = df.withColumn('dpc', 
                    f.when(f.col('address_line_1').rlike(pattern), f.lit('99'))
                    .otherwise(f.col('dpc')))

# %%
df.limit(25).toPandas()

# %%
df.groupBy('dpc').count().show()

# %%
df.filter(df.dpc == '99').limit(20).toPandas()

# %%
def apply_rule_2(df):
    # Use 99 when address contains no house number
    df = df.withColumn('dpc',f.when((f.col('dpc').isNull()) & (f.col('housenumber').isNull()),f.lit('99'))
                       .otherwise(f.col('dpc')))
    return df

class TestRule2(SparkTestCase):
    def test(self):
        # Test Case: Rule 2 should use 99 when the address contains no house number.
        # run a query that gives me the input that the function expects and the expected value from that
        # parse operation
        testdf = self.spark.sql("SELECT 'MAIN ST' AS address_line_1, CAST(NULL AS string) AS housenumber, CAST(NULL AS string) AS dpc, '99' AS expected")
        #run the function
        testdf = apply_rule_2(testdf)
        #gather the results [row 0 only] and compare the returned dpc to the expected dpc
        row = testdf.collect()[0]
        self.assertEquals(row.expected, row.dpc, "rule 2 fail; expected does not match dpc")

# %%
class TestRule1(SparkTestCase):
    def test(self):
        # Test Case: Rule 1 (General Rule) should provide the last two digits of a primary street number, 
        # post office box, rural route box, or highway contract route number
        # run a query that gives me the input that the function expects and the expected value from that
        # parse operation
        testdf = self.spark.sql("SELECT '1234 MAIN ST' AS address_line_1, CAST(NULL AS string) AS dpc, '34' AS expected")
        #run the function
        testdf = apply_rule_1(testdf)
        #gather the results [row 0 only] and compare the returned dpc to the expected dpc
        row = testdf.collect()[0]
        self.assertEquals(row.expected, row.dpc, "rule 1 created match")
