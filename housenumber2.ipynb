# %%
import os; import sys; import re

# common spark import
from pyspark import SparkFiles
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql.window import Window
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType

# connect to spark if we haven't already
if not 'spark' in locals():
  spark = SparkSession.builder \
      .master("local[*]") \
      .appName('development') \
      .config("spark.sql.debug.maxToStringFields", str(1024 * 1024)) \
      .getOrCreate()
  sc = spark.sparkContext

print("Connected to Spark!")
# Out:
# Connected to Spark!

# %%
df = spark.read.option("header", "true").csv("address-linkage-key/address_link/data/test/*small*.gz")
df.limit(10).toPandas()
# Out:
#   predirection streetname streetsuffix postdirection unitdesignator  \
# 0           S        Main         St
# 1                  Joseph         Ave
# 2               Algonquin         Way
# 3           N        Main         St                         Apt
# 4                   252nd         St
# 5                   Agean         Ct
# 6           W        43rd         St                         Apt
# 7               Muirfield         Run
# 8           NW       37th         St
# 9           N       Point         Blvd                       Apt
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                              Aspers    PA  17304   9802            S
# 1                           Westfield    MA  01085   1812            S
# 2                          Orangevale    CA  95662   2342            S
# 3             2           Crown Point    IN  46307   3279            M
# 4                         Harbor City    CA  90710   2422            S
# 5                            Murrieta    CA  92562   2118            S
# 6             25E            New York    NY  10036   6473            M
# 7                            Norcross    GA  30093   6100            S
# 8                       Coral Springs    FL  33065   2782            S
# 9             903         Tallahassee    FL  32308   4181            M
#
#        address_line_1 address_line_2 expected_dpc expected_check_digit
# 0       259 S Main St           None           59                    2
# 1       75 Joseph Ave           None           75                    2
# 2  8751 Algonquin Way           None           51                    5
# 3       250 N Main St          Apt 2           02                    7
# 4       1136 252nd St           None           36                    4
# 5      41484 Agean Ct           None           84                    2
# 6       350 W 43rd St        Apt 25E           55                    0
# 7  7302 Muirfield Run           None           02                    6
# 8    11075 NW 37th St           None           75                    2
# 9   1950 N Point Blvd        Apt 903           28                    0

# %%
def blanks_to_null(x):
    return f.when(f.col(x) != "", f.col(x)).otherwise(None)

# %%
def house_number_extract(df):
    #make address_line_1 all uppercase
    df = df.withColumn('address_line_1', f.upper('address_line_1'))
    
    #extract house number or box number into column housenumber
    df = df.withColumn('housenumber',
                      f.when(
                          df.address_line_1.rlike('^[A-Z]{2}'),
                          f.regexp_extract(f.col('address_line_1'),'(BOX\\s)([0-9]+[0-9A-Z.*-]*)', 2))
                       .otherwise(f.regexp_extract(f.col('address_line_1'),'^([A-Z]*[0-9]+[0-9A-Z.*-]*)', 1)))
    return df

# %%
df = house_number_extract(df)
df.limit(30).toPandas()
# Out:
#    predirection      streetname streetsuffix postdirection unitdesignator  \
# 0            S             Main         St
# 1                        Joseph         Ave
# 2                     Algonquin         Way
# 3            N             Main         St                         Apt
# 4                         252nd         St
# 5                         Agean         Ct
# 6            W             43rd         St                         Apt
# 7                     Muirfield         Run
# 8            NW            37th         St
# 9            N            Point         Blvd                       Apt
# 10                         10th         St
# 11                         28th         Ave                        Apt
# 12                     Pheasant         St
# 13                  Highway 120
# 14                Compass Point         Dr              N          Unit
# 15                    Yorkshire         Dr
# 16           N        Fairfield         Rd
# 17               County Road 73
# 18                      Florida         St
# 19                         26th         Pl              W          Apt
# 20                   Smooth Oak         Ln
# 21                     Rittiner         Dr
# 22                      Brattle         St
# 23                 Broken Fence         Dr
# 24           NW            54th         Way
# 25                      Arcadia         Dr
# 26           W      Highway 124
# 27                        Agnes         St
# 28           NW            38th         St
# 29                     Lusitano         Dr
#
#    unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                               Aspers    PA  17304   9802            S
# 1                            Westfield    MA  01085   1812            S
# 2                           Orangevale    CA  95662   2342            S
# 3              2           Crown Point    IN  46307   3279            M
# 4                          Harbor City    CA  90710   2422            S
# 5                             Murrieta    CA  92562   2118            S
# 6              25E            New York    NY  10036   6473            M
# 7                             Norcross    GA  30093   6100            S
# 8                        Coral Springs    FL  33065   2782            S
# 9              903         Tallahassee    FL  32308   4181            M
# 10                            Brooklyn    NY  11215   3908            S
# 11             1C             Flushing    NY  11354   1617            M
# 12                        West Roxbury    MA  02132   3012            S
# 13                            Robeline    LA  71469   5356            S
# 14             8             San Diego    CA  92126   5565            M
# 15                              Saline    MI  48176   9444            S
# 16                              Dayton    OH  45431   2557            S
# 17                            Florence    AL  35634   4104            S
# 18                       Elizabethport    NJ  07206   1543            S
# 19             104             Seattle    WA  98199   2043            M
# 20                             Houston    TX  77053   1118            S
# 21                         Baton Rouge    LA  70806   5463            S
# 22                           Cambridge    MA  02138   3347            S
# 23                              Medina    OH  44256   3302            S
# 24                         Gainesville    FL  32653   3266            S
# 25                          Sugar Land    TX  77498   2210            S
# 26                          Harrisburg    MO  65256   9344            S
# 27                             Gardner    KS  66030   8527            S
# 28                       Pembroke Pnes    FL  33024   5195            S
# 29                         Bloomington    CA  92316   3420            S
#
#               address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0              259 S MAIN ST           None           59                    2
# 1              75 JOSEPH AVE           None           75                    2
# 2         8751 ALGONQUIN WAY           None           51                    5
# 3              250 N MAIN ST          Apt 2           02                    7
# 4              1136 252ND ST           None           36                    4
# 5             41484 AGEAN CT           None           84                    2
# 6              350 W 43RD ST        Apt 25E           55                    0
# 7         7302 MUIRFIELD RUN           None           02                    6
# 8           11075 NW 37TH ST           None           75                    2
# 9          1950 N POINT BLVD        Apt 903           28                    0
# 10               276 10TH ST           None           76                    7
# 11            14116 28TH AVE         Apt 1C           13                    7
# 12            20 PHEASANT ST           None           20                    4
# 13          1944 HIGHWAY 120           None           44                    6
# 14  11595 COMPASS POINT DR N         Unit 8           08                    1
# 15         9055 YORKSHIRE DR           None           55                    3
# 16       2105 N FAIRFIELD RD           None           05                    9
# 17       7710 COUNTY ROAD 73           None           10                    9
# 18             73 FLORIDA ST           None           73                    2
# 19            3711 26TH PL W        Apt 104           29                    4
# 20        4718 SMOOTH OAK LN           None           18                    8
# 21          1005 RITTINER DR           None           05                    6
# 22            198 BRATTLE ST           None           98                    2
# 23       221 BROKEN FENCE DR           None           21                    8
# 24          6130 NW 54TH WAY           None           30                    1
# 25           2010 ARCADIA DR           None           10                    9
# 26        5970 W HIGHWAY 124           None           70                    9
# 27            16434 AGNES ST           None           34                    6
# 28           8546 NW 38TH ST           None           46                    8
# 29         18910 LUSITANO DR           None           10                    9
#
#    housenumber
# 0          259
# 1           75
# 2         8751
# 3          250
# 4         1136
# 5        41484
# 6          350
# 7         7302
# 8        11075
# 9         1950
# 10         276
# 11       14116
# 12          20
# 13        1944
# 14       11595
# 15        9055
# 16        2105
# 17        7710
# 18          73
# 19        3711
# 20        4718
# 21        1005
# 22         198
# 23         221
# 24        6130
# 25        2010
# 26        5970
# 27       16434
# 28        8546
# 29       18910

# %%
# run blank function on 'housenumber' column to replace blanks with 'None'.
df = df.withColumn('housenumber', blanks_to_null('housenumber'))

# %%
#rule1
df = df.withColumn('dpc', 
        f.when(
            f.col('address_line_2').isNull() &
            f.col('housenumber').isNotNull() & 
            f.col('housenumber').rlike('^[0-9]*$'),
            f.col('housenumber').substr(-2,2)))
df.limit(10).toPandas()
# Out:
#   predirection streetname streetsuffix postdirection unitdesignator  \
# 0           S        Main         St
# 1                  Joseph         Ave
# 2               Algonquin         Way
# 3           N        Main         St                         Apt
# 4                   252nd         St
# 5                   Agean         Ct
# 6           W        43rd         St                         Apt
# 7               Muirfield         Run
# 8           NW       37th         St
# 9           N       Point         Blvd                       Apt
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                              Aspers    PA  17304   9802            S
# 1                           Westfield    MA  01085   1812            S
# 2                          Orangevale    CA  95662   2342            S
# 3             2           Crown Point    IN  46307   3279            M
# 4                         Harbor City    CA  90710   2422            S
# 5                            Murrieta    CA  92562   2118            S
# 6             25E            New York    NY  10036   6473            M
# 7                            Norcross    GA  30093   6100            S
# 8                       Coral Springs    FL  33065   2782            S
# 9             903         Tallahassee    FL  32308   4181            M
#
#        address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0       259 S MAIN ST           None           59                    2
# 1       75 JOSEPH AVE           None           75                    2
# 2  8751 ALGONQUIN WAY           None           51                    5
# 3       250 N MAIN ST          Apt 2           02                    7
# 4       1136 252ND ST           None           36                    4
# 5      41484 AGEAN CT           None           84                    2
# 6       350 W 43RD ST        Apt 25E           55                    0
# 7  7302 MUIRFIELD RUN           None           02                    6
# 8    11075 NW 37TH ST           None           75                    2
# 9   1950 N POINT BLVD        Apt 903           28                    0
#
#   housenumber   dpc
# 0         259    59
# 1          75    75
# 2        8751    51
# 3         250  None
# 4        1136    36
# 5       41484    84
# 6         350  None
# 7        7302    02
# 8       11075    75
# 9        1950  None

# %%
#rule5
df = df.withColumn('dpc', 
                   f.when(
                       f.col('address_line_2').isNull() &
                       f.col('housenumber').isNotNull() & 
                       f.col('dpc').isNull() &
                       #f.col('housenumber').rlike('^[a-zA-Z0-9]*$'),
                       f.col('housenumber').rlike('^[0-9]+[A-Z]+$'),
                       f.regexp_extract(f.col('housenumber'),'(\d+)',1).substr(-2,2))
                   .otherwise(f.col('dpc')))
df.limit(10).toPandas()
# Out:
#   predirection streetname streetsuffix postdirection unitdesignator  \
# 0           S        Main         St
# 1                  Joseph         Ave
# 2               Algonquin         Way
# 3           N        Main         St                         Apt
# 4                   252nd         St
# 5                   Agean         Ct
# 6           W        43rd         St                         Apt
# 7               Muirfield         Run
# 8           NW       37th         St
# 9           N       Point         Blvd                       Apt
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                              Aspers    PA  17304   9802            S
# 1                           Westfield    MA  01085   1812            S
# 2                          Orangevale    CA  95662   2342            S
# 3             2           Crown Point    IN  46307   3279            M
# 4                         Harbor City    CA  90710   2422            S
# 5                            Murrieta    CA  92562   2118            S
# 6             25E            New York    NY  10036   6473            M
# 7                            Norcross    GA  30093   6100            S
# 8                       Coral Springs    FL  33065   2782            S
# 9             903         Tallahassee    FL  32308   4181            M
#
#        address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0       259 S MAIN ST           None           59                    2
# 1       75 JOSEPH AVE           None           75                    2
# 2  8751 ALGONQUIN WAY           None           51                    5
# 3       250 N MAIN ST          Apt 2           02                    7
# 4       1136 252ND ST           None           36                    4
# 5      41484 AGEAN CT           None           84                    2
# 6       350 W 43RD ST        Apt 25E           55                    0
# 7  7302 MUIRFIELD RUN           None           02                    6
# 8    11075 NW 37TH ST           None           75                    2
# 9   1950 N POINT BLVD        Apt 903           28                    0
#
#   housenumber   dpc
# 0         259    59
# 1          75    75
# 2        8751    51
# 3         250  None
# 4        1136    36
# 5       41484    84
# 6         350  None
# 7        7302    02
# 8       11075    75
# 9        1950  None

# %%
#rule8

# create new column that selects the first word from the address_line_1 string
df = df.withColumn('alphas', (f.regexp_extract(f.col('address_line_1'),'(^[A-Z0-9]+[0-9]\\w)', 1)))
    
# update dpc when alphas contains a value, add_line_2 is null and dpc is null
df = df.withColumn('dpc', 
        f.when(
            f.col('alphas').isNotNull() &
            f.col('address_line_2').isNull() &
            f.col('dpc').isNull(),
            f.regexp_extract(f.col('alphas'),'([0-9]{1,2}$)',1)).otherwise(f.col('dpc')))

df = df.withColumn('dpc', blanks_to_null('dpc'))

# %%
#rule10
df = df.withColumn('dpc', 
            f.when(
                #This specifies that if 'dpc' is not null, then that value should be retained.
                f.col('dpc').isNotNull(),
                f.col('dpc'))
                             .otherwise(f.regexp_extract(f.col('housenumber'), '([0-9]+)([.*-])([0-9]+)', 3)))

df = df.withColumn('dpc', blanks_to_null('dpc'))

df.limit(30).toPandas()
# Out:
#    predirection      streetname streetsuffix postdirection unitdesignator  \
# 0            S             Main         St
# 1                        Joseph         Ave
# 2                     Algonquin         Way
# 3            N             Main         St                         Apt
# 4                         252nd         St
# 5                         Agean         Ct
# 6            W             43rd         St                         Apt
# 7                     Muirfield         Run
# 8            NW            37th         St
# 9            N            Point         Blvd                       Apt
# 10                         10th         St
# 11                         28th         Ave                        Apt
# 12                     Pheasant         St
# 13                  Highway 120
# 14                Compass Point         Dr              N          Unit
# 15                    Yorkshire         Dr
# 16           N        Fairfield         Rd
# 17               County Road 73
# 18                      Florida         St
# 19                         26th         Pl              W          Apt
# 20                   Smooth Oak         Ln
# 21                     Rittiner         Dr
# 22                      Brattle         St
# 23                 Broken Fence         Dr
# 24           NW            54th         Way
# 25                      Arcadia         Dr
# 26           W      Highway 124
# 27                        Agnes         St
# 28           NW            38th         St
# 29                     Lusitano         Dr
#
#    unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                               Aspers    PA  17304   9802            S
# 1                            Westfield    MA  01085   1812            S
# 2                           Orangevale    CA  95662   2342            S
# 3              2           Crown Point    IN  46307   3279            M
# 4                          Harbor City    CA  90710   2422            S
# 5                             Murrieta    CA  92562   2118            S
# 6              25E            New York    NY  10036   6473            M
# 7                             Norcross    GA  30093   6100            S
# 8                        Coral Springs    FL  33065   2782            S
# 9              903         Tallahassee    FL  32308   4181            M
# 10                            Brooklyn    NY  11215   3908            S
# 11             1C             Flushing    NY  11354   1617            M
# 12                        West Roxbury    MA  02132   3012            S
# 13                            Robeline    LA  71469   5356            S
# 14             8             San Diego    CA  92126   5565            M
# 15                              Saline    MI  48176   9444            S
# 16                              Dayton    OH  45431   2557            S
# 17                            Florence    AL  35634   4104            S
# 18                       Elizabethport    NJ  07206   1543            S
# 19             104             Seattle    WA  98199   2043            M
# 20                             Houston    TX  77053   1118            S
# 21                         Baton Rouge    LA  70806   5463            S
# 22                           Cambridge    MA  02138   3347            S
# 23                              Medina    OH  44256   3302            S
# 24                         Gainesville    FL  32653   3266            S
# 25                          Sugar Land    TX  77498   2210            S
# 26                          Harrisburg    MO  65256   9344            S
# 27                             Gardner    KS  66030   8527            S
# 28                       Pembroke Pnes    FL  33024   5195            S
# 29                         Bloomington    CA  92316   3420            S
#
#               address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0              259 S MAIN ST           None           59                    2
# 1              75 JOSEPH AVE           None           75                    2
# 2         8751 ALGONQUIN WAY           None           51                    5
# 3              250 N MAIN ST          Apt 2           02                    7
# 4              1136 252ND ST           None           36                    4
# 5             41484 AGEAN CT           None           84                    2
# 6              350 W 43RD ST        Apt 25E           55                    0
# 7         7302 MUIRFIELD RUN           None           02                    6
# 8           11075 NW 37TH ST           None           75                    2
# 9          1950 N POINT BLVD        Apt 903           28                    0
# 10               276 10TH ST           None           76                    7
# 11            14116 28TH AVE         Apt 1C           13                    7
# 12            20 PHEASANT ST           None           20                    4
# 13          1944 HIGHWAY 120           None           44                    6
# 14  11595 COMPASS POINT DR N         Unit 8           08                    1
# 15         9055 YORKSHIRE DR           None           55                    3
# 16       2105 N FAIRFIELD RD           None           05                    9
# 17       7710 COUNTY ROAD 73           None           10                    9
# 18             73 FLORIDA ST           None           73                    2
# 19            3711 26TH PL W        Apt 104           29                    4
# 20        4718 SMOOTH OAK LN           None           18                    8
# 21          1005 RITTINER DR           None           05                    6
# 22            198 BRATTLE ST           None           98                    2
# 23       221 BROKEN FENCE DR           None           21                    8
# 24          6130 NW 54TH WAY           None           30                    1
# 25           2010 ARCADIA DR           None           10                    9
# 26        5970 W HIGHWAY 124           None           70                    9
# 27            16434 AGNES ST           None           34                    6
# 28           8546 NW 38TH ST           None           46                    8
# 29         18910 LUSITANO DR           None           10                    9
#
#    housenumber   dpc alphas
# 0          259    59    259
# 1           75    75
# 2         8751    51   8751
# 3          250  None    250
# 4         1136    36   1136
# 5        41484    84  41484
# 6          350  None    350
# 7         7302    02   7302
# 8        11075    75  11075
# 9         1950  None   1950
# 10         276    76    276
# 11       14116  None  14116
# 12          20    20
# 13        1944    44   1944
# 14       11595  None  11595
# 15        9055    55   9055
# 16        2105    05   2105
# 17        7710    10   7710
# 18          73    73
# 19        3711  None   3711
# 20        4718    18   4718
# 21        1005    05   1005
# 22         198    98    198
# 23         221    21    221
# 24        6130    30   6130
# 25        2010    10   2010
# 26        5970    70   5970
# 27       16434    34  16434
# 28        8546    46   8546
# 29       18910    10  18910

# %%
#rule13
df = df.withColumn('dpc', f.coalesce(f.col('dpc'), f.lit('99')))

# %%
#rule3
df = df.withColumn('dpc', f.lpad('dpc', 2, '0'))
df.limit(30).toPandas()
# Out:
#    predirection      streetname streetsuffix postdirection unitdesignator  \
# 0            S             Main         St
# 1                        Joseph         Ave
# 2                     Algonquin         Way
# 3            N             Main         St                         Apt
# 4                         252nd         St
# 5                         Agean         Ct
# 6            W             43rd         St                         Apt
# 7                     Muirfield         Run
# 8            NW            37th         St
# 9            N            Point         Blvd                       Apt
# 10                         10th         St
# 11                         28th         Ave                        Apt
# 12                     Pheasant         St
# 13                  Highway 120
# 14                Compass Point         Dr              N          Unit
# 15                    Yorkshire         Dr
# 16           N        Fairfield         Rd
# 17               County Road 73
# 18                      Florida         St
# 19                         26th         Pl              W          Apt
# 20                   Smooth Oak         Ln
# 21                     Rittiner         Dr
# 22                      Brattle         St
# 23                 Broken Fence         Dr
# 24           NW            54th         Way
# 25                      Arcadia         Dr
# 26           W      Highway 124
# 27                        Agnes         St
# 28           NW            38th         St
# 29                     Lusitano         Dr
#
#    unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                               Aspers    PA  17304   9802            S
# 1                            Westfield    MA  01085   1812            S
# 2                           Orangevale    CA  95662   2342            S
# 3              2           Crown Point    IN  46307   3279            M
# 4                          Harbor City    CA  90710   2422            S
# 5                             Murrieta    CA  92562   2118            S
# 6              25E            New York    NY  10036   6473            M
# 7                             Norcross    GA  30093   6100            S
# 8                        Coral Springs    FL  33065   2782            S
# 9              903         Tallahassee    FL  32308   4181            M
# 10                            Brooklyn    NY  11215   3908            S
# 11             1C             Flushing    NY  11354   1617            M
# 12                        West Roxbury    MA  02132   3012            S
# 13                            Robeline    LA  71469   5356            S
# 14             8             San Diego    CA  92126   5565            M
# 15                              Saline    MI  48176   9444            S
# 16                              Dayton    OH  45431   2557            S
# 17                            Florence    AL  35634   4104            S
# 18                       Elizabethport    NJ  07206   1543            S
# 19             104             Seattle    WA  98199   2043            M
# 20                             Houston    TX  77053   1118            S
# 21                         Baton Rouge    LA  70806   5463            S
# 22                           Cambridge    MA  02138   3347            S
# 23                              Medina    OH  44256   3302            S
# 24                         Gainesville    FL  32653   3266            S
# 25                          Sugar Land    TX  77498   2210            S
# 26                          Harrisburg    MO  65256   9344            S
# 27                             Gardner    KS  66030   8527            S
# 28                       Pembroke Pnes    FL  33024   5195            S
# 29                         Bloomington    CA  92316   3420            S
#
#               address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0              259 S MAIN ST           None           59                    2
# 1              75 JOSEPH AVE           None           75                    2
# 2         8751 ALGONQUIN WAY           None           51                    5
# 3              250 N MAIN ST          Apt 2           02                    7
# 4              1136 252ND ST           None           36                    4
# 5             41484 AGEAN CT           None           84                    2
# 6              350 W 43RD ST        Apt 25E           55                    0
# 7         7302 MUIRFIELD RUN           None           02                    6
# 8           11075 NW 37TH ST           None           75                    2
# 9          1950 N POINT BLVD        Apt 903           28                    0
# 10               276 10TH ST           None           76                    7
# 11            14116 28TH AVE         Apt 1C           13                    7
# 12            20 PHEASANT ST           None           20                    4
# 13          1944 HIGHWAY 120           None           44                    6
# 14  11595 COMPASS POINT DR N         Unit 8           08                    1
# 15         9055 YORKSHIRE DR           None           55                    3
# 16       2105 N FAIRFIELD RD           None           05                    9
# 17       7710 COUNTY ROAD 73           None           10                    9
# 18             73 FLORIDA ST           None           73                    2
# 19            3711 26TH PL W        Apt 104           29                    4
# 20        4718 SMOOTH OAK LN           None           18                    8
# 21          1005 RITTINER DR           None           05                    6
# 22            198 BRATTLE ST           None           98                    2
# 23       221 BROKEN FENCE DR           None           21                    8
# 24          6130 NW 54TH WAY           None           30                    1
# 25           2010 ARCADIA DR           None           10                    9
# 26        5970 W HIGHWAY 124           None           70                    9
# 27            16434 AGNES ST           None           34                    6
# 28           8546 NW 38TH ST           None           46                    8
# 29         18910 LUSITANO DR           None           10                    9
#
#    housenumber dpc alphas
# 0          259  59    259
# 1           75  75
# 2         8751  51   8751
# 3          250  99    250
# 4         1136  36   1136
# 5        41484  84  41484
# 6          350  99    350
# 7         7302  02   7302
# 8        11075  75  11075
# 9         1950  99   1950
# 10         276  76    276
# 11       14116  99  14116
# 12          20  20
# 13        1944  44   1944
# 14       11595  99  11595
# 15        9055  55   9055
# 16        2105  05   2105
# 17        7710  10   7710
# 18          73  73
# 19        3711  99   3711
# 20        4718  18   4718
# 21        1005  05   1005
# 22         198  98    198
# 23         221  21    221
# 24        6130  30   6130
# 25        2010  10   2010
# 26        5970  70   5970
# 27       16434  34  16434
# 28        8546  46   8546
# 29       18910  10  18910
