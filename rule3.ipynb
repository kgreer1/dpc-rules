# %%
import os; import sys; import re

# common spark import
from pyspark import SparkFiles
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql.window import Window
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType

# connect to spark if we haven't already
if not 'spark' in locals():
  spark = SparkSession.builder \
      .master("local[*]") \
      .appName('development') \
      .config("spark.sql.debug.maxToStringFields", str(1024 * 1024)) \
      .getOrCreate()
  sc = spark.sparkContext

print("Connected to Spark!")
# Out:
# Connected to Spark!

# %%
df = spark.read.option("header", "true").csv("address-linkage-key/address_link/data/test/*medium*.gz")
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit
# 0        525 Circle Dr           None           25                    0
# 1    2312 Primrose Ave           None           12                    2
# 2  849 Gardenstone Cir           None           49                    8
# 3    7511 Briarwood Dr           None           11                    0
# 4       1071 S 15th St           None           71                    4
# 5         206 Front St         Apt 4B           42                    1
# 6     1295 Millpond Rd           None           95                    1
# 7      479 Glenwood Ln           None           79                    8
# 8       2150 NW 9th St        Apt 105           30                    9
# 9       460 10th St NE           None           60                    0

# %%
df = df.withColumn('dpc', f.lit(None))

# %%
df = df.withColumn('housenumber', (f.regexp_extract(f.col('address_line_1'),'(^[0-9]([0-9A-Z.*-]+)?)', 1)))
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit   dpc  \
# 0        525 Circle Dr           None           25                    0  None
# 1    2312 Primrose Ave           None           12                    2  None
# 2  849 Gardenstone Cir           None           49                    8  None
# 3    7511 Briarwood Dr           None           11                    0  None
# 4       1071 S 15th St           None           71                    4  None
# 5         206 Front St         Apt 4B           42                    1  None
# 6     1295 Millpond Rd           None           95                    1  None
# 7      479 Glenwood Ln           None           79                    8  None
# 8       2150 NW 9th St        Apt 105           30                    9  None
# 9       460 10th St NE           None           60                    0  None
#
#   housenumber
# 0         525
# 1        2312
# 2         849
# 3        7511
# 4        1071
# 5         206
# 6        1295
# 7         479
# 8        2150
# 9         460

# %%
#rule1
df = df.withColumn('dpc',
                   f.when(
                       f.col('address_line_2').isNull() &
                       f.col('housenumber').isNotNull() &
                       f.col('housenumber').rlike('^[0-9]*$'),
                       f.col('housenumber').substr(-2,2)
))
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit   dpc  \
# 0        525 Circle Dr           None           25                    0    25
# 1    2312 Primrose Ave           None           12                    2    12
# 2  849 Gardenstone Cir           None           49                    8    49
# 3    7511 Briarwood Dr           None           11                    0    11
# 4       1071 S 15th St           None           71                    4    71
# 5         206 Front St         Apt 4B           42                    1  None
# 6     1295 Millpond Rd           None           95                    1    95
# 7      479 Glenwood Ln           None           79                    8    79
# 8       2150 NW 9th St        Apt 105           30                    9  None
# 9       460 10th St NE           None           60                    0    60
#
#   housenumber
# 0         525
# 1        2312
# 2         849
# 3        7511
# 4        1071
# 5         206
# 6        1295
# 7         479
# 8        2150
# 9         460

# %%
df.filter(df.address_line_1.contains("Box")).limit(10).toPandas()
# Out:
#   predirection streetname streetsuffix postdirection unitdesignator  \
# 0                  PO Box
# 1                  PO Box
# 2                  PO Box
# 3                  PO Box
# 4                  PO Box
# 5                  PO Box
# 6                  PO Box
# 7                  PO Box
# 8                  PO Box
# 9                  PO Box
#
#   unitdesignatornumber      cityname state zipcode zip_4 dwellingtype  \
# 0                            Andover    KS  67002   0901            U
# 1                       Olive Branch    MS  38654   2104            S
# 2                           Sweetser    IN  46987   0108            U
# 3                            Hanover    PA  17331   0745            S
# 4                           Monrovia    MD  21770   0212            U
# 5                             Perrin    TX  76486   0177            S
# 6                             Estill    SC  29918   1351            U
# 7                        Hattiesburg    MS  39404   7214            U
# 8                            Fayette    MS  39069   0293            U
# 9                        Winterville    NC  28590   1249            S
#
#   address_line_1 address_line_2 expected_dpc expected_check_digit dpc  \
# 0     901 PO Box           None           01                    4  01
# 1    1992 PO Box           None           92                    6  92
# 2     108 PO Box           None           08                    9  08
# 3     745 PO Box           None           45                    0  45
# 4     212 PO Box           None           12                    5  12
# 5     177 PO Box           None           77                    0  77
# 6    1351 PO Box           None           51                    5  51
# 7   17214 PO Box           None           14                    1  14
# 8     293 PO Box           None           93                    7  93
# 9    1249 PO Box           None           49                    7  49
#
#   housenumber
# 0         901
# 1        1992
# 2         108
# 3         745
# 4         212
# 5         177
# 6        1351
# 7       17214
# 8         293
# 9        1249

# %%
#rule2
df = df.withColumn('dpc', 
                   f.when((f.col('dpc').isNull()) & (f.col('housenumber').isNull()), 
                          f.lit('99'))
                   .otherwise(f.col('dpc'))
                  )
df.limit(10).toPandas()
# Out:
#   predirection   streetname streetsuffix postdirection unitdesignator  \
# 0                    Circle         Dr
# 1                  Primrose         Ave
# 2               Gardenstone         Cir
# 3                 Briarwood         Dr
# 4           S          15th         St
# 5                     Front         St                         Apt
# 6                  Millpond         Rd
# 7                  Glenwood         Ln
# 8           NW          9th         St                         Apt
# 9                      10th         St              NE
#
#   unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                         Fort Morgan    CO  80701   3419            S
# 1                               Vista    CA  92083   8032            S
# 2                           Tallmadge    OH  44278   1085            S
# 3                           Crestwood    KY  40014   9019            S
# 4                         Saint Clair    MI  48079   5203            S
# 5             4B             Brooklyn    NY  11201   1223            M
# 6                       Elizabeth Cty    NC  27909   7551            S
# 7                         East Meadow    NY  11554   3719            S
# 8             105               Miami    FL  33125   3443            M
# 9                              Naples    FL  34120   2057            S
#
#         address_line_1 address_line_2 expected_dpc expected_check_digit   dpc  \
# 0        525 Circle Dr           None           25                    0    25
# 1    2312 Primrose Ave           None           12                    2    12
# 2  849 Gardenstone Cir           None           49                    8    49
# 3    7511 Briarwood Dr           None           11                    0    11
# 4       1071 S 15th St           None           71                    4    71
# 5         206 Front St         Apt 4B           42                    1  None
# 6     1295 Millpond Rd           None           95                    1    95
# 7      479 Glenwood Ln           None           79                    8    79
# 8       2150 NW 9th St        Apt 105           30                    9  None
# 9       460 10th St NE           None           60                    0    60
#
#   housenumber
# 0         525
# 1        2312
# 2         849
# 3        7511
# 4        1071
# 5         206
# 6        1295
# 7         479
# 8        2150
# 9         460

# %%
#172
df.filter(df.dpc == '1').count()
# Out:
# 172

# %%
df.filter(df.dpc == '01').count()
# Out:
# 2117

# %%
#df.filter(df.dpc == '1').limit(10).toPandas()
df.filter(f.length('dpc') == 1).limit(10).toPandas()
# Out:
#   predirection     streetname streetsuffix postdirection unitdesignator  \
# 0                      Purdue         Cir
# 1                     Freeman         Ln
# 2                  Rolph Park         Ct
# 3                      Garlor         Dr
# 4                      Heaton         Cir
# 5                 Mockingbird         Ct
# 6                     Hopkins         St
# 7                     Beacham         Pl
# 8               Pleasant Hill         Rd
# 9                    Sweitzer         Dr
#
#   unitdesignatornumber     cityname state zipcode zip_4 dwellingtype  \
# 0                       Little Rock    AR  72204   5949            S
# 1                          Poquoson    VA  23662   1906            S
# 2                          Crockett    CA  94525   1414            S
# 3                         Havertown    PA  19083   1214            S
# 4                          Franklin    MA  02038   3368            S
# 5                         Waterford    NY  12188   1509            S
# 6                          Unadilla    NY  13849   2304            S
# 7                           Hingham    MA  02043   3331            S
# 8                          Falmouth    ME  04105   1965            S
# 9                       Duke Center    PA  16729   9504            S
#
#        address_line_1 address_line_2 expected_dpc expected_check_digit dpc  \
# 0        1 Purdue Cir           None           01                    7   1
# 1        8 Freeman Ln           None           08                    7   8
# 2     2 Rolph Park Ct           None           02                    3   2
# 3         1 Garlor Dr           None           01                    0   1
# 4        4 Heaton Cir           None           04                    3   4
# 5    2 Mockingbird Ct           None           02                    3   2
# 6        8 Hopkins St           None           08                    8   8
# 7        2 Beacham Pl           None           02                    9   2
# 8  6 Pleasant Hill Rd           None           06                    3   6
# 9       6 Sweitzer Dr           None           06                    1   6
#
#   housenumber
# 0           1
# 1           8
# 2           2
# 3           1
# 4           4
# 5           2
# 6           8
# 7           2
# 8           6
# 9           6

# %%
#rule 3 with lpad
#df = df.withColumn('dpc', f.lpad('dpc', 2, '0'))
#df.limit(20).toPandas()

# %%
#rule 3 with lpad and more logic
#only lpad if dpc is not length=2
df = df.withColumn('dpc', 
                   f.when(
                       f.length('dpc') == 2, 
                       f.col('dpc'))
                   .otherwise( 
                       f.lpad('dpc', 2, '0')))
df.limit(20).toPandas()
# Out:
#    predirection      streetname streetsuffix postdirection unitdesignator  \
# 0                        Circle         Dr
# 1                      Primrose         Ave
# 2                   Gardenstone         Cir
# 3                     Briarwood         Dr
# 4            S             15th         St
# 5                         Front         St                         Apt
# 6                      Millpond         Rd
# 7                      Glenwood         Ln
# 8            NW             9th         St                         Apt
# 9                          10th         St              NE
# 10                      Hil Mar         Dr                         Apt
# 11                       PO Box
# 12                          Ash         St
# 13           N             11th         St
# 14                          Ely         St
# 15                      Stroika         Ct
# 16               Music Mountain         Rd                         Lot
# 17           N              300                         E
# 18           NW            30th         Ct                         Apt
# 19                       PO Box
#
#    unitdesignatornumber       cityname state zipcode zip_4 dwellingtype  \
# 0                          Fort Morgan    CO  80701   3419            S
# 1                                Vista    CA  92083   8032            S
# 2                            Tallmadge    OH  44278   1085            S
# 3                            Crestwood    KY  40014   9019            S
# 4                          Saint Clair    MI  48079   5203            S
# 5              4B             Brooklyn    NY  11201   1223            M
# 6                        Elizabeth Cty    NC  27909   7551            S
# 7                          East Meadow    NY  11554   3719            S
# 8              105               Miami    FL  33125   3443            M
# 9                               Naples    FL  34120   2057            S
# 10             201        District Hts    MD  20747   4105            M
# 11                             Andover    KS  67002   0901            U
# 12                             Webster    MA  01570   3060            S
# 13                        Collinsville    OK  74021   2019            S
# 14                             Allegan    MI  49010   1419            S
# 15                             Crivitz    WI  54114   8204            S
# 16             2             Morganton    NC  28655   9917            M
# 17                          Valparaiso    IN  46383   8345            S
# 18             109       Ft Lauderdale    FL  33322   2045            M
# 19                        Olive Branch    MS  38654   2104            S
#
#             address_line_1 address_line_2 expected_dpc expected_check_digit  \
# 0            525 Circle Dr           None           25                    0
# 1        2312 Primrose Ave           None           12                    2
# 2      849 Gardenstone Cir           None           49                    8
# 3        7511 Briarwood Dr           None           11                    0
# 4           1071 S 15th St           None           71                    4
# 5             206 Front St         Apt 4B           42                    1
# 6         1295 Millpond Rd           None           95                    1
# 7          479 Glenwood Ln           None           79                    8
# 8           2150 NW 9th St        Apt 105           30                    9
# 9           460 10th St NE           None           60                    0
# 10         6509 Hil Mar Dr        Apt 201           51                    4
# 11              901 PO Box           None           01                    4
# 12               39 Ash St           None           39                    6
# 13           719 N 11th St           None           19                    4
# 14              404 Ely St           None           04                    7
# 15        N7255 Stroika Ct           None           55                    1
# 16  3256 Music Mountain Rd          Lot 2           02                    6
# 17             510 N 300 E           None           10                    5
# 18        10360 NW 30th Ct        Apt 109           34                    9
# 19             1992 PO Box           None           92                    6
#
#      dpc housenumber
# 0     25         525
# 1     12        2312
# 2     49         849
# 3     11        7511
# 4     71        1071
# 5   None         206
# 6     95        1295
# 7     79         479
# 8   None        2150
# 9     60         460
# 10  None        6509
# 11    01         901
# 12    39          39
# 13    19         719
# 14    04         404
# 15    00
# 16  None        3256
# 17    10         510
# 18  None       10360
# 19    92        1992

# %%
df.filter(f.length('dpc') == 1).limit(10).toPandas()
# Out:
# Empty DataFrame
# Columns: [predirection, streetname, streetsuffix, postdirection, unitdesignator, unitdesignatornumber, cityname, state, zipcode, zip_4, dwellingtype, address_line_1, address_line_2, expected_dpc, expected_check_digit, dpc, housenumber]
# Index: []

# %%
df.filter(df.dpc == '1').count()
# Out:
# 0

# %%
#2289
df.filter(df.dpc == '01').count()
# Out:
# 2289

# %% [markdown]
# df = df.withColumn('dpc', f.when(f.col('dpc').isNotNull(), f.col('dpc')).otherwise(
#     whatever you want to do
# )

# %%
#rule3 mod
df = df.withColumn('dpc',
                   f.when(
                       f.col('housenumber').rlike('\d{2}'),
                       f.col('dpc'))
                   .otherwise(f.concat(f.lit('0'), f.col('dpc')))
                  )

# %%
#rule3 
#when house number contains a single digit, add a leading zero
#when housenumber contains two digits, leave existing dpc, otherwise add a leading 0
df = df.withColumn('dpc',
                   f.when(
                       f.col('dpc').rlike('\d{2}'),
                       f.col('dpc'))
                   .otherwise(f.concat(f.lit('0'), f.col('dpc')))
                  )
df.filter(df.housenumber == '1').limit(10).toPandas()

# %%
df.limit(30).toPandas()

# %%
df.filter(df.housenumber.rlike('^\d{1}$')).limit(10).toPandas()

# %%
df.filter(df.housenumber.rlike('\d{2}')).limit(10).toPandas()

# %%
df.filter(df.dpc == '01' & df.housenumber == '1').count()

# %%
df.limit(30).toPandas()

# %%
# rule 3
df = df.withColumn('dpc',
                   f.when(
                       f.col('dpc').rlike('\d{2,}'),f.col('dpc'))
                          .otherwise(f.lit('test'))
                         )


df = df.withColumn('dpc', 
                   f.when((f.col('housenumber') == "1")),
                         f.regexp_extract(f.col('housenumber'),'(\d{2,})', 1)
                   .otherwise(f.col('dpc'))
                  )
